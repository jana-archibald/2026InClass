# %% [markdown]
# ## In Class September 22

# %% [markdown]
# If you want to run this code you can use the link on Moodle to get a copy of this notebook (and this dataset).

# %%
census <- read.csv("census150.csv",header=TRUE)

# %% [markdown]
# When you run the code above, it looks like nothing happens. But the dataset is being loaded in the background. If you do not run the code the rest of the commands in the notebook will not run.
#
# The first thing I like to do is use `head` and `tail` to see some of the data.

# %%
head(census)
# Out:
#   census_year state_fips_code total_family_income age sex    race_general
# 1 2000        Alabama          5500               73  Female Black
# 2 2000        Alabama         63820               40  Male   White
# 3 2000        Arizona         45000               48  Male   Japanese
# 4 2000        Arizona             0               67  Female White
# 5 2000        Arizona         46800               53  Female White
# 6 2000        Arizona         30000               60  Female White
#   marital_status         total_personal_income percent_family_income
# 1 Divorced                3000                  54.54545
# 2 Married/spouse present 47950                  75.13319
# 3 Married/spouse present 45000                 100.00000
# 4 Widowed                    0                   0.00000
# 5 Married/spouse absent  30000                  64.10256
# 6 Widowed                30000                 100.00000

# %%
tail(census)
# Out:
#     census_year state_fips_code total_family_income age sex    race_general
# 145 2000        Washington       48200              71  Male   White
# 146 2000        Wisconsin       175000              61  Male   White
# 147 2000        Wisconsin        45000              29  Female White
# 148 2000        Wisconsin        72520              31  Male   White
# 149 2000        Wisconsin        34500              63  Male   White
# 150 2000        Wyoming         146000              12  Female White
#     marital_status         total_personal_income percent_family_income
# 145 Married/spouse present 42600                  88.38174
# 146 Married/spouse present 55000                  31.42857
# 147 Married/spouse present 20000                  44.44444
# 148 Married/spouse present 39510                  54.48152
# 149 Divorced               34500                 100.00000
# 150 Never married/single       0                   0.00000

# %% [markdown]
# ## We will be looking at the personal income variable

# %%
plot(census$total_personal_income)
# Out:
# plot without title

# %% [markdown]
# This is not a useful plot

# %% [markdown]
# ## What is a typical personal income?
#
# Lets compute some numerical summaries

# %%
mean(census$total_personal_income)
median(census$total_personal_income)
# Out:
# [1] 21643.68
# [1] 14250

# %%
summary(census$total_personal_income)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0   14250   21644   31200  160000

# %% [markdown]
# ## Lets take a better look at this data.

# %%
hist(census$total_personal_income)
# Out:
# Plot with title “Histogram of census$total_personal_income”

# %%
hist(census$total_personal_income,breaks=15)
# Out:
# Plot with title “Histogram of census$total_personal_income”

# %% [markdown]
# Once you have a histogram you like you can use `xlab` and `main` to change the labels on the axis.

# %% [markdown]
# ## We didn't get this far on Tuesday but I will leave these plots here for later.

# %%
par(mfrow=c(2,1))
hist(census$total_personal_income)

boxplot(census$total_personal_income,horizontal=T)
# Out:
# Plot with title “Histogram of census$total_personal_income”
